# %%
from ultralytics import YOLO
# Out:
# /Users/hanliyang/Documents/GitHub/Parkinson-Prediagnosis/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
model = YOLO('yolov8n-pose.pt')

# %%
results = model(source= "/Users/hanliyang/Documents/GitHub/PD data/Videos/PDFE01_1.mp4", show = True, conf = 0.3, save = True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/3598) /Users/hanliyang/Documents/GitHub/PD data/Videos/PDFE01_1.mp4: 384x640 2 persons, 192.2ms
# video 1/1 (frame 2/3598) /Users/hanliyang/Documents/GitHub/PD data/Videos/PDFE01_1.mp4: 384x640 2 persons, 156.2ms
# video 1/1 (frame 3/3598) /Users/hanliyang/Documents/GitHub/PD data/Videos/PDFE01_1.mp4: 384x640 2 persons, 118.9ms
# ...
