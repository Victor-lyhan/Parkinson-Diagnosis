# %%
import pandas as pd
import numpy as np

# %%
video_data_path = "../Computer Vision/Results/p1v2/p1v2_results.csv"
df_p1v2 = pd.read_csv(video_data_path, encoding = 'latin-1').dropna()

# %%
#pd.set_option('display.max_columns', None)
df_p1v2_Core = df_p1v2.iloc[:, [12, 13]]
df_p1v2_Core #linear acceleration, angular velocity
# Out:
#       angular_velocity  linear_acceleration
# 2             0.121215           -30.852290
# 3            -0.556502           -83.042684
# 4             0.847324           166.904951
# 5             2.197242           150.184794
# 6             0.809987          -181.772989
# ...                ...                  ...
# 3670          2.172544           248.187326
# 3671         -0.456686          -337.951332
# 3672         -2.992782          -330.429194
# 3673          1.821059           617.176007
# 3674          1.647167           -22.461201
#
# [3673 rows x 2 columns]

# %%
# added FoG ratio, time, and UPDRS-III
Patient_All_Data = "../Example/Data/PDFEinfo.csv"
df_all = pd.read_csv(Patient_All_Data, encoding='latin-1', sep=';')

FogRatioTimeUPDRSIII = df_all.iloc[0, [32, 43, 45]].values.astype(float)

for _ in range(5 - df_p1v2_Core.shape[1]):
    df_p1v2_Core[f'new_col_{df_p1v2_Core.shape[1]}'] = 0

column_mapping = {df_p1v2_Core.columns[2]: 'UPDRS-III', 
                  df_p1v2_Core.columns[3]: 'FoG Total Time', 
                  df_p1v2_Core.columns[4]: 'FoG Ratio'}
df_p1v2_Core.rename(columns=column_mapping, inplace=True)


df_p1v2_Core.loc[:, 'UPDRS-III'] = FogRatioTimeUPDRSIII[0]
df_p1v2_Core.loc[:, 'FoG Total Time'] = FogRatioTimeUPDRSIII[1]
df_p1v2_Core.loc[:, 'FoG Ratio'] = FogRatioTimeUPDRSIII[2]


df_p1v2_Core['UPDRS-III'] = df_p1v2_Core['UPDRS-III'].astype(float)
df_p1v2_Core['FoG Total Time'] = df_p1v2_Core['FoG Total Time'].astype(float)
df_p1v2_Core['FoG Ratio'] = df_p1v2_Core['FoG Ratio'].astype(float)
# Out:
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_17628\275043769.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_p1v2_Core[f'new_col_{df_p1v2_Core.shape[1]}'] = 0
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_17628\275043769.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_p1v2_Core[f'new_col_{df_p1v2_Core.shape[1]}'] = 0
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_17628\275043769.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_p1v2_Core[f'new_col_{df_p1v2_Core.shape[1]}'] = 0
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_17628\275043769.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_p1v2_Core.rename(columns=column_mapping, inplace=True)
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_17628\275043769.py:17: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '115.96' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_p1v2_Core.loc[:, 'FoG Total Time'] = FogRatioTimeUPDRSIII[1]
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_17628\275043769.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '17.94' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_p1v2_Core.loc[:, 'FoG Ratio'] = FogRatioTimeUPDRSIII[2]
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_17628\275043769.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_p1v2_Core['UPDRS-III'] = df_p1v2_Core['UPDRS-III'].astype(float)
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_17628\275043769.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_p1v2_Core['FoG Total Time'] = df_p1v2_Core['FoG Total Time'].astype(float)
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_17628\275043769.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_p1v2_Core['FoG Ratio'] = df_p1v2_Core['FoG Ratio'].astype(float)

# %%
import matplolib.pyplot as plt
