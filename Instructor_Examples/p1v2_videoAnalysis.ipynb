# %%
import pandas as pd
import numpy as np

# %%
df_p1v2_core = pd.read_csv('Results/p1v2/df_p1v2_core.csv',encoding = 'latin-1')
df_p1v2_core
# Out:
#       angular_velocity  linear_acceleration  UPDRS-III  FoG Total Time  \
# 0             0.121215           -30.852290       14.0          115.96
# 1            -0.556502           -83.042684       14.0          115.96
# 2             0.847324           166.904951       14.0          115.96
# 3             2.197242           150.184794       14.0          115.96
# 4             0.809987          -181.772989       14.0          115.96
# ...                ...                  ...        ...             ...
# 3668          2.172544           248.187326       14.0          115.96
# 3669         -0.456686          -337.951332       14.0          115.96
# 3670         -2.992782          -330.429194       14.0          115.96
# 3671          1.821059           617.176007       14.0          115.96
# 3672          1.647167           -22.461201       14.0          115.96
#
#       FoG Ratio
# 0         17.94
# 1         17.94
# 2         17.94
# 3         17.94
# 4         17.94
# ...

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
